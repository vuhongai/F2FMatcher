# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
from utils_CP_flows import *
from configs import *
import pandas as pd

# %%
img1, img2 = 'AV_260625_22-082_10X_TA1c1_WGA-1', 'AV_260625_22-082_10X_TA1c2_WGA-1'
images_dir = "/DATA/fiber_matcher/images"

# %%
path_img1 = f"{images_dir}/{img1}.png"
path_img2 = f"{images_dir}/{img2}.png"

df = pd.read_csv('/DATA/fiber_matcher/datasets/training_data_260625.csv')
compare_2_slides(path_img1, path_img2, plot_annotated_pairs=True, df_pair=df,)
# Out:
# /DATA/fiber_matcher/training_fibermatcher/utils_CP_flows.py:410: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_0.ROI_I2 = [int(i) for i in df_0.ROI_I2.tolist()]
