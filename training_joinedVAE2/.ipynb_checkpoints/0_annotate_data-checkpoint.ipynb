# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
from utils_CP_flows import *
from configs import *
import pandas as pd

# %%
path_img1 = f"{images_dir}/TA21c2-1.png"
path_img2 = f"{images_dir}/TA21c3-1.png"

df = pd.read_csv(f'{dir_dataset}/training_data_260625.csv')
compare_2_slides(path_img1, path_img2, plot_partial=True, df_pair=df,)
# Out:
# /DATA/fiber_matcher/training_AE/utils_CP_flows.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_0.ROI_I2 = [int(i) for i in df_0.ROI_I2.tolist()]
