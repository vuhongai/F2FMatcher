# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
from utils_CP_flows import *
from configs import *
import pandas as pd

# %%
path_img1 = f"{images_dir}/TA33c1-4.png"
path_img2 = f"{images_dir}/TA33c2-4.png"

df = pd.read_csv(f'{dir_dataset}/training_data_260625.csv')
compare_2_slides(path_img1, path_img2, plot_partial=True, df_pair=df,)
# Out:
# /DATA/fiber_matcher/training_joinedVAE2/utils_CP_flows.py:406: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_0.ROI_I2 = [int(i) for i in df_0.ROI_I2.tolist()]
